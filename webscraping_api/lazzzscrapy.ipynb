# %%
import requests

#Go to dev tools, select network, filter to XHR or docs, review requests (usually the largest), get header info
#modify this however you need to query the api e.g. sorting, page (experiment on the website first!)
url = 'https://www.lazada.com.ph/shop-makeup/?ajax=true&page=1'

#copy relevant header info
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36',
    'X-Requested-With': 'XMLHttpRequest',
    'Referer': 'https://www.lazada.com.ph/shop-makeup/',
}    

r = requests.get(url, headers=headers)

# this is the "page" data 
data = r.json()

# %%
data
# Out:
# {'mods': {'filter': {'tItemType': 'nt_filter',
#    'filterItems': [{'options': [{'value': 'shop-makeup',
#        'title': 'Makeup',
#        'url': '/shop-makeup/',
#        'order': 0,
#        'id': '5378'}],
#      'isPreposed': False,
#      'preposeOrder': 0,
#      'name': 'category',
#      'type': 'category',
#      'unfoldRow': '-1',
#      'title': 'Related Categories',
#      'urlKey': 'category',
#      'value': 'shop-makeup',
#      'displayValue': 'Makeup',
#      'hidden': False,
#      'locked': False},
#     {'pid': '20000',
#      'options': [{'value': 'born-pretty_1',
#        'title': 'BORN PRETTY',
#        'order': 0},
#       {'value': 'garnier', 'title': 'Garnier', 'order': 0},
#       {'value': 'myyeah-123339285', 'title': 'myyeah', 'order': 0},
#       {'value': 'sweet-night-227041', 'title': 'Sweet Night', 'order': 0},
#       {'value': 'modelones-110080814', 'title': 'Modelones', 'order': 0},
#       {'value': 'brilliant-skin-essentials',
#        'title': 'Brilliant Skin Essentials',
#        'order': 0},
#       {'value': 'melede-123886487', 'title': 'MELEDE', 'order': 0},
#       {'value': 'mumuso-200138', 'title': 'Mumuso', 'order': 0},
#       {'value': 'sace-lady-206915', 'title': 'SACE LADY', 'order': 0},
#       {'value': 'kleenfant-123777624', 'title': 'Kleenfant', 'order': 0},
#       {'value': 'maange', 'title': 'MAANGE', 'order': 0},
#       {'value': 'ponds', 'title': "Pond's", 'order': 0},
#       {'value': 'purederm', 'title': 'Purederm', 'order': 0},
#       {'value': 'choice-beauty-123683004',
#        'title': 'Choice Beauty',
#        'order': 0},
#       {'value': 'fabiyan-122837213', 'title': 'FABIYAN', 'order': 0},
#       {'value': 'nivea', 'title': 'Nivea', 'order': 0},
#       {'value': 'biore', 'title': 'Biore', 'order': 0},
#       {'value': 'kimuse-206316', 'title': 'KIMUSE', 'order': 0},
#       {'value': 'banila-co', 'title': 'Banila Co', 'order': 0},
#       {'value': 'proda', 'title': 'PRODA', 'order': 0},
#       {'value': 'ashley', 'title': 'Ashley', 'order': 0},
#       {'value': 'eskinol_1', 'title': 'Eskinol', 'order': 0},
#       {'value': 'lameila_1', 'title': 'Lameila', 'order': 0},
#       {'value': 'focallure_1', 'title': 'Focallure', 'order': 0},
#       {'value': 'focano-123892433', 'title': 'FOCANO', 'order': 0},
#       {'value': 'aboutface-225845', 'title': 'aboutface', 'order': 0},
#       {'value': 'avon', 'title': 'AVON', 'order': 0},
#       {'value': 'yealon_1', 'title': 'YEALON', 'order': 0}],
#      'isPreposed': False,
#      'preposeOrder': 0,
#      'name': 'brand',
#      'type': 'brand',
#      'unfoldRow': '2',
#      'title': 'Brand',
#      'urlKey': 'ppath',
#      'value': [],
#      'hidden': False,
#      'locked': False},
#     {'options': [{'value': 'official', 'title': 'LazMall', 'order': 0},
#       {'value': 'gc', 'title': 'LazGlobal', 'order': 1},
#       {'value': 'COD', 'title': 'Cash On Delivery', 'order': 4},
#       {'value': 'FBL', 'title': 'Fulfilled By Lazada', 'order': 5},
#       {'value': 'freeShipping', 'title': 'Free Shipping', 'order': 6}],
#      'isPreposed': False,
#      'preposeOrder': 0,
#      'name': 'service',
#      'type': 'multiple',
#      'unfoldRow': '2',
#      'title': 'Service',
#      'urlKey': 'service',
#      'value': [],
#      'hidden': False,
#      'locked': False},
#     {'options': [{'value': 'Local', 'title': 'Local', 'order': 0},
#       {'value': 'Overseas', 'title': 'Overseas', 'order': 0},
#       {'value': 'Metro Manila', 'title': 'Metro Manila', 'order': 0},
#       {'value': 'Abra', 'title': 'Abra', 'order': 0},
#       {'value': 'Bulacan', 'title': 'Bulacan', 'order': 0},
#       {'value': 'Laguna', 'title': 'Laguna', 'order': 0},
#       {'value': 'Cavite', 'title': 'Cavite', 'order': 0},
#       {'value': 'Rizal', 'title': 'Rizal', 'order': 0},
#       {'value': 'Nueva Ecija', 'title': 'Nueva Ecija', 'order': 0},
#       {'value': 'Davao Del Sur', 'title': 'Davao Del Sur', 'order': 0},
#       {'value': 'Pampanga', 'title': 'Pampanga', 'order': 0},
#       {'value': 'Cebu', 'title': 'Cebu', 'order': 0},
#       {'value': 'Batangas', 'title': 'Batangas', 'order': 0},
#       {'value': 'Zambales', 'title': 'Zambales', 'order': 0}],
#      'isPreposed': False,
#      'preposeOrder': 0,
#      'name': 'location',
#      'type': 'multiple',
#      'unfoldRow': '2',
#      'title': 'Location',
#      'urlKey': 'location',
#      'value': [],
#      'hidden': False,
#      'locked': False},
#     {'options': [],
#      'showMin': 'Min',
#      'showMax': 'Max',
#      'name': 'price',
#      'type': 'price',
#      'unfoldRow': '2',
#      'title': 'Price',
#      'urlKey': 'price',
#      'hidden': False,
#      'locked': False},
#     {'name': 'rating',
#      'type': 'rating',
#      'unfoldRow': '2',
#      'title': 'Rating',
#      'urlKey': 'rating',
#      'value': '0',
#      'hidden': False,
#      'locked': False},
#     {'pid': '100005642',
#      'options': [{'value': '100005642:587', 'title': 'Pink', 'order': 0},
#       {'value': '100005642:242', 'title': 'Green', 'order': 0},
#       {'value': '100005642:404', 'title': 'Red', 'order': 0},
#       {'value': '100005642:1254', 'title': 'Yellow', 'order': 0},
#       {'value': '100005642:1411', 'title': 'Rose', 'order': 0},
#       {'value': '100005642:134', 'title': 'Black', 'order': 0},
#       {'value': '100005642:130278', 'title': 'Blue Gray', 'order': 0},
#       {'value': '100005642:80342', 'title': 'Multicolor', 'order': 0},
#       {'value': '100005642:169', 'title': 'Clear', 'order': 0},
#       {'value': '100005642:48793', 'title': 'White', 'order': 0},
#       {'value': '100005642:54', 'title': 'Cream', 'order': 0},
#       {'value': '100005642:104207', 'title': '…', 'order': 0},
#       {'value': '100005642:1780', 'title': 'Blue', 'order': 0},
#       {'value': '100005642:1611', 'title': 'Cherry', 'order': 0},
#       {'value': '100005642:146', 'title': 'Brown', 'order': 0},
#       {'value': '100005642:1781', 'title': 'Blueberry', 'order': 0},
#       {'value': '100005642:56961', 'title': 'Silver', 'order': 0},
#       {'value': '100005642:80359', 'title': 'Olive', 'order': 0},
#       {'value': '100005642:78669', 'title': 'Chili Red', 'order': 0},
#       {'value': '100005642:68946', 'title': 'Purple', 'order': 0},
#       {'value': '100005642:528', 'title': 'Jade', 'order': 0},
#       {'value': '100005642:1884', 'title': 'Rainbow', 'order': 0},
#       {'value': '100005642:75851', 'title': 'Grey', 'order': 0},
#       {'value': '100005642:76166', 'title': 'Watermelon red', 'order': 0},
#       {'value': '100005642:115', 'title': 'Aqua', 'order': 0},
#       {'value': '100005642:2066', 'title': 'Orange', 'order': 0},
#       {'value': '100005642:80446', 'title': 'Violet', 'order': 0},
#       {'value': '100005642:76705', 'title': 'Beige', 'order': 0},
#       {'value': '100005642:196331', 'title': 'Rose Red', 'order': 0}],
#      'isPreposed': False,
#      'preposeOrder': 0,
#      'name': 'attribute',
#      'type': 'multiple',
#      'unfoldRow': '0',
#      'title': 'Color',
#      'urlKey': 'ppath',
#      'value': [],
#      'hidden': False,
#      'locked': False},
#     {'pid': '100007519',
#      'options': [{'value': '100007519:169951',
#        'title': 'Single Item',
#        'order': 0},
#       {'value': '100007519:145968', 'title': 'Multi-pack', 'order': 0}],
#      'isPreposed': False,
#      'preposeOrder': 0,
#      'name': 'attribute',
#      'type': 'multiple',
#      'unfoldRow': '0',
#      'title': 'Pack Type',
#      'urlKey': 'ppath',
#      'value': [],
#      'hidden': False,
#      'locked': False},
#     {'pid': '100007518',
#      'options': [{'value': '100007518:926', 'title': 'Premium', 'order': 0},
#       {'value': '100007518:6718', 'title': 'Mass', 'order': 0},
#       {'value': '100007518:169949', 'title': 'Dermacare', 'order': 0},
#       {'value': '100007518:169950', 'title': 'Masstige', 'order': 0}],
#      'isPreposed': False,
#      'preposeOrder': 0,
#      'name': 'attribute',
#      'type': 'multiple',
#      'unfoldRow': '0',
#      'title': 'Brand Classification',
#      'urlKey': 'ppath',
#      'value': [],
#      'hidden': False,
#      'locked': False},
#     {'pid': '100007419',
#      'options': [{'value': '100007419:149136',
#        'title': 'Long-wear',
#        'order': 0},
#       {'value': '100007419:149140', 'title': 'High Pigmentation', 'order': 0},
#       {'value': '100007419:149138', 'title': 'Hydrating', 'order': 0},
#       {'value': '100007419:149141', 'title': 'Spf', 'order': 0}],
#      'isPreposed': False,
#      'preposeOrder': 0,
#      'name': 'attribute',
#      'type': 'multiple',
#      'unfoldRow': '0',
#      'title': 'Lips Makeup Benefits',
#      'urlKey': 'ppath',
#      'value': [],
#      'hidden': False,
#      'locked': False},
#     {'pid': '100006657',
#      'options': [{'value': '100006657:99271', 'title': 'Normal', 'order': 0},
#       {'value': '100006657:85087', 'title': 'Combination', 'order': 0},
#       {'value': '100006657:64536', 'title': 'Dry', 'order': 0},
#       {'value': '100006657:88659', 'title': 'Oily', 'order': 0},
#       {'value': '100006657:82474', 'title': 'Sensitive', 'order': 0},
#       {'value': '100006657:76691', 'title': 'Acne-prone', 'order': 0},
#       {'value': '100006657:75846', 'title': 'Dull', 'order': 0},
#       {'value': '100006657:110078249', 'title': 'All types', 'order': 0},
#       {'value': '100006657:101169', 'title': 'Signs of Ageing', 'order': 0}],
#      'isPreposed': False,
#      'preposeOrder': 0,
#      'name': 'attribute',
#      'type': 'multiple',
#      'unfoldRow': '0',
#      'title': 'Skin Type',
#      'urlKey': 'ppath',
#      'value': [],
#      'hidden': False,
#      'locked': False},
#     {'pid': '120150202',
#      'options': [{'value': '120150202:149930',
#        'title': 'Paraben-free',
#        'order': 0},
#       {'value': '120150202:123812008', 'title': 'Alcohol-free', 'order': 0},
#       {'value': '120150202:145362', 'title': 'Hypo-Allergenic', 'order': 0},
#       {'value': '120150202:149929', 'title': 'Fragrance-Free', 'order': 0},
#       {'value': '120150202:123812013', 'title': 'Vitamins', 'order': 0},
#       {'value': '120150202:147712', 'title': 'Mineral', 'order': 0},
#       {'value': '120150202:169937', 'title': 'Hyaluronic Acid', 'order': 0},
#       {'value': '120150202:96047', 'title': 'Serum', 'order': 0},
#       {'value': '120150202:123811490', 'title': 'Oil-free', 'order': 0},
#       {'value': '120150202:123812011', 'title': 'Sulphate-free', 'order': 0},
#       {'value': '120150202:123811488', 'title': 'Amino Acid', 'order': 0},
#       {'value': '120150202:123811493', 'title': 'Salicylic Acid', 'order': 0}],
#      'isPreposed': False,
#      'preposeOrder': 0,
#      'name': 'attribute',
#      'type': 'multiple',
#      'unfoldRow': '0',
#      'title': 'Ingredient',
#      'urlKey': 'ppath',
#      'value': [],
#      'hidden': False,
#      'locked': False},
#     {'pid': '100007411',
#      'options': [{'value': '100007411:8951', 'title': 'Liquid', 'order': 0},
#       {'value': '100007411:149134', 'title': 'Micellar Water', 'order': 0},
#       {'value': '100007411:80468', 'title': 'Wipes', 'order': 0},
#       {'value': '100007411:54', 'title': 'Cream', 'order': 0},
#       {'value': '100007411:99045', 'title': 'Balm', 'order': 0},
#       {'value': '100007411:88642', 'title': 'Oil-Based', 'order': 0},
#       {'value': '100007411:70223', 'title': 'Other', 'order': 0},
#       {'value': '100007411:85154', 'title': 'Foam', 'order': 0}],
#      'isPreposed': False,
#      'preposeOrder': 0,
#      'name': 'attribute',
#      'type': 'multiple',
#      'unfoldRow': '0',
#      'title': 'Product Form',
#      'urlKey': 'ppath',
#      'value': [],
#      'hidden': False,
#      'locked': False}],
#    'filteredQuatity': '6221135',
#    'filteredDoneText': 'Product',
#    'bizData': 'Related+Categories=Makeup',
#    'pos': 0},
#   'listItems': [{'name': 'Vinka Organic green tea Facial Tissue 3 ply (480 sheets） x 8 Packs',
#     'nid': '499100801',
#     'icons': [{'domClass': 'Bn6ZZf',
#       'alias': 'Bn6ZZf',
#       'type': 'img',
#       'group': '6',
#       'showType': '0',
#       'order': 0,
#       'font-size': 0,
#       'coins': False},
#      {'domClass': 'yAbuyy',
#       'alias': 'yAbuyy',
#       'type': 'img',
#       'group': '3',
#       'showType': '0',
#       'order': 0,
#       'font-size': 0,
#       'coins': False}],
#     'utLogMap': {'x_object_type': 'item',
#      'x_item_ids': '499100801',
#      'scene_pre': 'search',
#      'current_price': '125',
#      'x_sku_ids': '1325420019',
#      'SN': 'dc973ea1b940bc80e9c3b6fb10fcd826',
#      'x_ad': '1',
#      'x_object_id': '499100801'},
#     'image': 'https://ph-test-11.slatic.net/p/7f49ea88a8bb71dbecba23bd1914146c.jpg',
#     'originalPrice': '388.00',
#     'originalPriceShow': '₱388',
#     'price': '125',
#     'promotionId': 'null',
#     'priceShow': '₱125',
#     'discount': '-68%',
#     'ratingScore': '4.9313821138211384',
#     'review': '3075',
#     'installment': '',
#     'tItemType': 'nt_product',
#     'location': 'Metro Manila',
#     'cheapest_sku': '499100801_PH-1325420019',
#     'sku': '499100801_PH',
#     'skus': [],
#     'description': ['Vinka Facial Tissue (480sheets x 8 packs)Made from 100% natural virgin fibersUniquely enrich with Green Tea extractDurable with 3-ply thickness that is silky, smooth and softPerfect for removing makeups, sniffles, and sneezesvinka facial tissue can be used in living rooms, bathrooms, kitchens, offices, classroom, vehicle &amp; moreProvide strength, absorbency, and a clean white appearanceEach pack has a top opening for smooth dispensing of 1 sheet at a timeEach pack has 480 sheets, size of each sheet is 150mm x 180 mmMade from all organic materials, no harmful chemicals addedGood quality facial tissue'],
#     'brandId': '29872',
#     'brandName': 'No Brand',
#     'sellerId': '1000077277',
#     'mainSellerId': '',
#     'sellerName': 'DLMA',
#     'thumbs': [{'image': 'https://ph-live-01.slatic.net/p/7f49ea88a8bb71dbecba23bd1914146c.jpg',
#       'sku': '499100801_PH',
#       'skuId': '1325420019',
#       'itemUrl': '/products/vinka-organic-green-tea-facial-tissue-3-ply-480-sheets-x-8-packs-i499100801.html',
#       'querystring': ''},
#      {'image': 'https://ph-live-01.slatic.net/p/a6538c8f0ae0507764f36dde3a43f304.jpg',
#       'sku': '499100801_PH',
#       'skuId': '15960120986',
#       'itemUrl': '/products/vinka-organic-green-tea-facial-tissue-3-ply-480-sheets-x-8-packs-i499100801.html',
#       'querystring': ''}],
#     'restrictedAge': 0,
#     'categories': [7644, 5378, 5405, 5464],
#     'clickTrace': 'query:;nid:499100801;src:LazadaMainSrp;rn:dc973ea1b940bc80e9c3b6fb10fcd826;region:ph;sku:499100801_PH;price:125;client:desktop;supplier_id:1000077277;asc_category_id:5464;item_id:499100801;sku_id:1325420019;shop_id:255877',
#     'addToCartSkus': [{'sku': '499100801_PH-1325420019',
#       'skuId': '1325420019',
#       'count': 0}],
#     'itemId': '499100801',
#     'skuId': '1325420019',
#     'inStock': True,
#     'isAD': 0,
#     'addToCart': False,
#     'showFeedBack': False,
#     'longImageDisplayable': False,
#     'itemUrl': '//www.lazada.com.ph/products/vinka-organic-green-tea-facial-tissue-3-ply-480-sheets-x-8-packs-i499100801.html',
#     'querystring': 'search=1&clickTrackInfo=query%253A%253Bnid%253A499100801%253Bsrc%253ALazadaMainSrp%253Brn%253Adc973ea1b940bc80e9c3b6fb10fcd826%253Bregion%253Aph%253Bsku%253A499100801_PH%253Bprice%253A125%253Bclient%253Adesktop%253Bsupplier_id%253A1000077277%253Basc_category_id%253A5464%253Bitem_id%253A499100801%253Bsku_id%253A1325420019%253Bshop_id%253A255877'},
#    {'name': 'MAS SHOP vinka Organic Facial Tissue 3 ply (360 sheets x 8 Packs)',
#     'nid': '415644659',
#     'icons': [{'domClass': 'Bn6ZZf',
#       'alias': 'Bn6ZZf',
#       'type': 'img',
#       'group': '6',
#       'showType': '0',
#       'order': 0,
#       'font-size': 0,
#       'coins': False},
#      {'domClass': 'yAbuyy',
#       'alias': 'yAbuyy',
#       'type': 'img',
#       'group': '3',
#       'showType': '0',
#       'order': 0,
#       'font-size': 0,
#       'coins': False}],
#     'utLogMap': {'x_object_type': 'item',
#      'x_item_ids': '415644659',
#      'scene_pre': 'search',
#      'current_price': '112.4',
#      'x_sku_ids': '1016076259',
#      'SN': 'dc973ea1b940bc80e9c3b6fb10fcd826',
#      'x_ad': '1',
#      'x_object_id': '415644659'},
#     'image': 'https://ph-test-11.slatic.net/p/076564b874ebe25883c4b9305a2bf649.jpg',
#     'originalPrice': '299.00',
#     'originalPriceShow': '₱299',
#     'price': '112.4',
#     'promotionId': 'null',
#     'priceShow': '₱112.4',
#     'discount': '-62%',
#     'ratingScore': '4.910551454624403',
#     'review': '2303',
#     'installment': '',
#     'tItemType': 'nt_product',
#     'location': 'Metro Manila',
#     'cheapest_sku': '415644659_PH-1016076259',
#     'sku': '415644659_PH',
#     'skus': [],
#     'description': ['Vinka Facial Tissue (360sheets x 8 packs)',
#      'Made from 100% natural virgin fibers',
#      'Uniquely enrich with Green Tea extract',
#      'Durable with 3-ply thickness that is silky, smooth and soft',
#      'Perfect for removing makeups, sniffles, and sneezes',
#      'Vinka facial tissue can be used in living rooms, bathrooms, kitchens, offices, classroom, vehicle &amp; more',
#      'Provide strength, absorbency, and a clean white appearance',
#      'Each pack has a top opening for smooth dispensing of 1 sheet at a time',
#      'Each pack has 360 sheets, size of each sheet is 130mm x 180 mm',
#      'Made from all organic materials, no harmful chemicals added',
#      'Good quality facial tissue',
#      'One item per order number only. For 2 quantities or more, please split your orders to save on shipping fees'],
#     'brandId': '29872',
#     'brandName': 'No Brand',
#     'sellerId': '1000253031',
#     'mainSellerId': '',
#     'sellerName': 'MAS shop',
#     'thumbs': [{'image': 'https://ph-live-01.slatic.net/p/076564b874ebe25883c4b9305a2bf649.jpg',
#       'sku': '415644659_PH',
#       'skuId': '1016076259',
#       'itemUrl': '/products/mas-shop-vinka-organic-facial-tissue-3-ply-360-sheets-x-8-packs-i415644659.html',
#       'querystring': ''}],
#     'restrictedAge': 0,
#     'categories': [7644, 5378, 5405, 5464],
#     'clickTrace': 'query:;nid:415644659;src:LazadaMainSrp;rn:dc973ea1b940bc80e9c3b6fb10fcd826;region:ph;sku:415644659_PH;price:112.4;client:desktop;supplier_id:1000253031;asc_category_id:5464;item_id:415644659;sku_id:1016076259;shop_id:426198',
#     'addToCartSkus': [{'sku': '415644659_PH-1016076259',
#       'skuId': '1016076259',
#       'count': 0}],
#     'itemId': '415644659',
#     'skuId': '1016076259',
#     'inStock': True,
#     'isAD': 0,
#     'addToCart': False,
#     'showFeedBack': False,
#     'longImageDisplayable': False,
#     'itemUrl': '//www.lazada.com.ph/products/mas-shop-vinka-organic-facial-tissue-3-ply-360-sheets-x-8-packs-i415644659.html',
#     'querystring': 'search=1&clickTrackInfo=query%253A%253Bnid%253A415644659%253Bsrc%253ALazadaMainSrp%253Brn%253Adc973ea1b940bc80e9c3b6fb10fcd826%253Bregion%253Aph%253Bsku%253A415644659_PH%253Bprice%253A112.4%253Bclient%253Adesktop%253Bsupplier_id%253A1000253031%253Basc_category_id%253A5464%253Bitem_id%253A415644659%253Bsku_id%253A1016076259%253Bshop_id%253A426198'},
#    {'name': 'F.six Liquid eyeliner pen is waterproof and sweatproof, long-lasting and does not smudge eyeliner FS ✨Buy ₱199 Free shipping✨✌',
#     'nid': '1728450184',
#     'icons': [{'domClass': 'RveiUb',
#       'alias': 'RveiUb',
#       'type': 'img',
#       'group': '6',
#       'showType': '0',
#       'order': 0,
#       'font-size': 0,
#       'coins': False},
#      {'domClass': 'yAbuyy',
#       'alias': 'yAbuyy',
#       'type': 'img',
#       'group': '3',
#       'showType': '0',
#       'order': 0,
#       'font-size': 0,
#       'coins': False}],
#     'utLogMap': {'x_object_type': 'item',
#      'x_item_ids': '1728450184',
#      'scene_pre': 'search',
#      'current_price': '10.7',
#      'x_sku_ids': '7450704051',
#      'SN': 'dc973ea1b940bc80e9c3b6fb10fcd826',
#      'x_ad': '1',
#      'x_object_id': '1728450184'},
#     'image': 'https://ph-test-11.slatic.net/p/0cc18a741cedce560a09aa02eb00cb7a.jpg',
#     'originalPrice': '55.00',
#     'originalPriceShow': '₱55',
#     'price': '10.7',
#     'promotionId': 'null',
#     'priceShow': '₱10.7',
#     'discount': '-81%',
#     'ratingScore': '4.811353711790393',
#     'review': '3435',
#     'installment': '',
#     'tItemType': 'nt_product',
#     'location': 'Metro Manila',
#     'cheapest_sku': '1728450184_PH-7450704051',
#     'sku': '1728450184_PH',
#     'skus': [],
#     'description': ['Product Features:',
#      'Liquid eyeliner pen has waterproof , sweatproof , not blooming and long lasting etc function',
#      'waterproof liquid liner that use with ease won&#39;t smudge and stays in place until you say when!The thin marker-like tip is easy to use even for the least experienced.Its highly pigmented formula gives you bold, even, streak free line in a single stroke.',
#      'Water-proof,high-pigmented makes your liner last all day',
#      'How To Use:',
#      'To apply, simply shake the product (if using a felt tip&ndash;this will saturate the felt tip with liquid), and start at the outer lash line. Sweep the liquid eyeliner along the upper lash line in small, connected strokes, continuing until you reach the inner corner of your eye.',
#      'Warm Tips:',
#      'It is liquid pen, it is convenient and save your time',
#      'Package Contents:',
#      '1 x eyeliner pen'],
#     'brandId': '29872',
#     'brandName': 'No Brand',
#     'sellerId': '1000276953',
#     'mainSellerId': '',
#     'sellerName': 'F.six',
#     'thumbs': [{'image': 'https://ph-live-01.slatic.net/p/e6ad9c1b29af93072e5593dfe6c6e41b.jpg',
#       'sku': '1728450184_PH',
#       'skuId': '7450704051',
#       'itemUrl': '/products/fsix-liquid-eyeliner-pen-is-waterproof-and-sweatproof-long-lasting-and-does-not-smudge-eyeliner-fs-buy-199-free-shipping-i1728450184.html',
#       'querystring': ''}],
#     'restrictedAge': 0,
#     'categories': [7644, 5378, 5412, 5451],
#     'clickTrace': 'query:;nid:1728450184;src:LazadaMainSrp;rn:dc973ea1b940bc80e9c3b6fb10fcd826;region:ph;sku:1728450184_PH;price:10.7;client:desktop;supplier_id:1000276953;asc_category_id:5451;item_id:1728450184;sku_id:7450704051;shop_id:448766',
#     'addToCartSkus': [{'sku': '1728450184_PH-7450704051',
#       'skuId': '7450704051',
#       'count': 0}],
#     'itemId': '1728450184',
#     'skuId': '7450704051',
#     'inStock': True,
#     'isAD': 0,
#     'addToCart': False,
#     'showFeedBack': False,
#     'longImageDisplayable': False,
#     'itemUrl': '//www.lazada.com.ph/products/fsix-liquid-eyeliner-pen-is-waterproof-and-sweatproof-long-lasting-and-does-not-smudge-eyeliner-fs-buy-199-free-shipping-i1728450184.html',
#     'querystring': 'search=1&clickTrackInfo=query%253A%253Bnid%253A1728450184%253Bsrc%253ALazadaMainSrp%253Brn%253Adc973ea1b940bc80e9c3b6fb10fcd826%253Bregion%253Aph%253Bsku%253A1728450184_PH%253Bprice%253A10.7%253Bclient%253Adesktop%253Bsupplier_id%253A1000276953%253Basc_category_id%253A5451%253Bitem_id%253A1728450184%253Bsku_id%253A7450704051%253Bshop_id%253A448766'},
#    {'name': 'U HOME vinka Organic Facial Tissue 3 ply (360 sheets x 8 Packs)',
#     'nid': '1278880227',
#     'icons': [{'domClass': 'Bn6ZZf',
#       'alias': 'Bn6ZZf',
#       'type': 'img',
#       'group': '6',
#       'showType': '0',
#       'order': 0,
#       'font-size': 0,
#       'coins': False},
#      {'domClass': 'yAbuyy',
#       'alias': 'yAbuyy',
#       'type': 'img',
#       'group': '3',
#       'showType': '0',
#       'order': 0,
#       'font-size': 0,
#       'coins': False}],
#     'utLogMap': {'x_object_type': 'item',
#      'x_item_ids': '1278880227',
#      'scene_pre': 'search',
#      'current_price': '105',
#      'x_sku_ids': '4629848598',
#      'SN': 'dc973ea1b940bc80e9c3b6fb10fcd826',
#      'x_ad': '1',
#      'x_object_id': '1278880227'},
#     'image': 'https://ph-test-11.slatic.net/p/b301f421a54ee28e88573e26df519dfe.jpg',
#     'originalPrice': '299.00',
#     'originalPriceShow': '₱299',
#     'price': '105',
#     'promotionId': 'null',
#     'priceShow': '₱105',
#     'discount': '-65%',
#     'ratingScore': '4.935708752904725',
#     'review': '1291',
#     'installment': '',
#     'tItemType': 'nt_product',
#     'location': 'Metro Manila',
#     'cheapest_sku': '1278880227_PH-4629848598',
#     'sku': '1278880227_PH',
#     'skus': [],
#     'description': ['Vinka Facial Tissue (360sheets x 8 packs)',
#      'Made from 100% natural virgin fibers',
#      'Uniquely enrich with Green Tea extract',
#      'Durable with 3-ply thickness that is silky, smooth and soft',
#      'Perfect for removing makeups, sniffles, and sneezes',
#      'Vinka facial tissue can be used in living rooms, bathrooms, kitchens, offices, classroom, vehicle &amp; more',
#      'Provide strength, absorbency, and a clean white appearance',
#      'Each pack has a top opening for smooth dispensing of 1 sheet at a time',
#      'Each pack has 360 sheets, size of each sheet is 130mm x 180 mm',
#      'Made from all organic materials, no harmful chemicals added',
#      'Good quality facial tissue',
#      'One item per order number only. For 2 quantities or more, please split your orders to save on shipping fees'],
#     'brandId': '29872',
#     'brandName': 'No Brand',
#     'sellerId': '500157765453',
#     'mainSellerId': '',
#     'sellerName': 'U home',
#     'thumbs': [{'image': 'https://ph-test-11.slatic.net/p/b301f421a54ee28e88573e26df519dfe.jpg',
#       'sku': '1278880227_PH',
#       'skuId': '4629848598',
#       'itemUrl': '/products/u-home-vinka-organic-facial-tissue-3-ply-360-sheets-x-8-packs-i1278880227.html',
#       'querystring': ''}],
#     'restrictedAge': 0,
#     'categories': [7644, 5378, 5405, 5464],
#     'clickTrace': 'query:;nid:1278880227;src:LazadaMainSrp;rn:dc973ea1b940bc80e9c3b6fb10fcd826;region:ph;sku:1278880227_PH;price:105;client:desktop;supplier_id:500157765453;asc_category_id:5464;item_id:1278880227;sku_id:4629848598;shop_id:731884',
#     'addToCartSkus': [{'sku': '1278880227_PH-4629848598',
#       'skuId': '4629848598',
#       'count': 0}],
#     'itemId': '1278880227',
#     'skuId': '4629848598',
#     'inStock': True,
#     'isAD': 0,
#     'addToCart': False,
#     'showFeedBack': False,
#     'longImageDisplayable': False,
#     'itemUrl': '//www.lazada.com.ph/products/u-home-vinka-organic-facial-tissue-3-ply-360-sheets-x-8-packs-i1278880227.html',
#     'querystring': 'search=1&clickTrackInfo=query%253A%253Bnid%253A1278880227%253Bsrc%253ALazadaMainSrp%253Brn%253Adc973ea1b940bc80e9c3b6fb10fcd826%253Bregion%253Aph%253Bsku%253A1278880227_PH%253Bprice%253A105%253Bclient%253Adesktop%253Bsupplier_id%253A500157765453%253Basc_category_id%253A5464%253Bitem_id%253A1278880227%253Bsku_id%253A4629848598%253Bshop_id%253A731884'},
#    {'name': 'SUNISA Mushroom Head Air Cushion BB CC Cream (With Sponge)',
#     'nid': '808864655',
#     'icons': [],
#     'utLogMap': {'x_object_type': 'item',
#      'x_item_ids': '808864655',
#      'scene_pre': 'search',
#      'current_price': '78.00',
#      'x_sku_ids': '13753823222',
#      'SN': 'dc973ea1b940bc80e9c3b6fb10fcd826',
#      'x_ad': '1',
#      'x_object_id': '808864655'},
#     'image': 'https://sg-test-11.slatic.net/p/a3ec916396b209056cc0756a48a16294.jpg',
#     'originalPrice': '199.00',
#     'originalPriceShow': '₱199',
#     'price': '78.00',
#     'promotionId': 'null',
#     'priceShow': '₱78',
#     'discount': '-61%',
#     'ratingScore': '4.86275565123789',
#     'review': '1858',
#     'installment': '',
#     'tItemType': 'nt_product',
#     'location': 'Metro Manila',
#     'cheapest_sku': '808864655_PH-13753823222',
#     'sku': '808864655_PH',
#     'skus': [],
#     'description': ['Product informationBrand: Sunisa Mushroom Head Air CushionColor: ivory whiteApplicable Skin Quality: UniversalCategory: BB CreamShelf life: 3 yearsPackage Included:1*BB Cream+1*Sponge'],
#     'brandId': '29872',
#     'brandName': 'No Brand',
#     'sellerId': '1000025037',
#     'mainSellerId': '',
#     'sellerName': 'Silent angel',
#     'thumbs': [{'image': 'https://sg-test-11.slatic.net/p/a3ec916396b209056cc0756a48a16294.jpg',
#       'sku': '808864655_PH',
#       'skuId': '13753823222',
#       'itemUrl': '/products/sunisa-mushroom-head-air-cushion-bb-cc-cream-with-sponge-i808864655.html',
#       'querystring': ''}],
#     'restrictedAge': 0,
#     'categories': [7644, 5378, 5414, 9452],
#     'clickTrace': 'query:;nid:808864655;src:LazadaMainSrp;rn:dc973ea1b940bc80e9c3b6fb10fcd826;region:ph;sku:808864655_PH;price:78.00;client:desktop;supplier_id:1000025037;asc_category_id:9452;item_id:808864655;sku_id:13753823222;shop_id:203958',
#     'addToCartSkus': [{'sku': '808864655_PH-13753823222',
#       'skuId': '13753823222',
#       'count': 0}],
#     'itemId': '808864655',
#     'skuId': '13753823222',
#     'inStock': True,
#     'isAD': 0,
#     'addToCart': False,
#     'showFeedBack': False,
#     'longImageDisplayable': False,
#     'itemUrl': '//www.lazada.com.ph/products/sunisa-mushroom-head-air-cushion-bb-cc-cream-with-sponge-i808864655.html',
#     'querystring': 'search=1&clickTrackInfo=query%253A%253Bnid%253A808864655%253Bsrc%253ALazadaMainSrp%253Brn%253Adc973ea1b940bc80e9c3b6fb10fcd826%253Bregion%253Aph%253Bsku%253A808864655_PH%253Bprice%253A78.00%253Bclient%253Adesktop%253Bsupplier_id%253A1000025037%253Basc_category_id%253A9452%253Bitem_id%253A808864655%253Bsku_id%253A13753823222%253Bshop_id%253A203958'},
#    {'name': '2 In1 Concealer Highlight Shadow Face Contouring Makeup Kiki Beauty & Care',
#     'nid': '1924312498',
#     'icons': [{'domClass': 'Bn6ZZf',
#       'alias': 'Bn6ZZf',
#       'type': 'img',
#       'group': '6',
#       'showType': '0',
#       'order': 0,
#       'font-size': 0,
#       'coins': False}],
#     'utLogMap': {'x_object_type': 'item',
#      'x_item_ids': '1924312498',
#      'scene_pre': 'search',
#      'current_price': '27',
#      'x_sku_ids': '8229991020',
#      'SN': 'dc973ea1b940bc80e9c3b6fb10fcd826',
#      'x_ad': '1',
#      'x_object_id': '1924312498'},
#     'image': 'https://ph-test-11.slatic.net/p/80f469bb42e40f52b2f4bc5cf2f0e224.jpg',
#     'originalPrice': '179.00',
#     'originalPriceShow': '₱179',
#     'price': '27',
#     'promotionId': 'null',
#     'priceShow': '₱27',
#     'discount': '-85%',
#     'ratingScore': '4.845598845598846',
#     'review': '693',
#     'installment': '',
#     'tItemType': 'nt_product',
#     'location': 'Metro Manila',
#     'cheapest_sku': '1924312498_PH-8229991020',
#     'sku': '1924312498_PH',
#     'skus': [],
#     'description': [],
#     'brandId': '29872',
#     'brandName': 'No Brand',
#     'sellerId': '500173734222',
#     'mainSellerId': '',
#     'sellerName': 'Kiki.beauty.and.care',
#     'thumbs': [{'image': 'https://ph-live-01.slatic.net/p/9e8f56f1e50c78c683eb271724b2086d.jpg',
#       'sku': '1924312498_PH',
#       'skuId': '8229991020',
#       'itemUrl': '/products/2-in1-concealer-highlight-shadow-face-contouring-makeup-kiki-beauty-care-i1924312498.html',
#       'querystring': ''}],
#     'restrictedAge': 0,
#     'categories': [7644, 5378, 5414, 7708],
#     'clickTrace': 'query:;nid:1924312498;src:LazadaMainSrp;rn:dc973ea1b940bc80e9c3b6fb10fcd826;region:ph;sku:1924312498_PH;price:27;client:desktop;supplier_id:500173734222;asc_category_id:7708;item_id:1924312498;sku_id:8229991020;shop_id:2134505',
#     'addToCartSkus': [{'sku': '1924312498_PH-8229991020',
#       'skuId': '8229991020',
#       'count': 0}],
#     'itemId': '1924312498',
#     'skuId': '8229991020',
#     'inStock': True,
#     'isAD': 0,
#     'addToCart': False,
#     'showFeedBack': False,
#     'longImageDisplayable': False,
#     'itemUrl': '//www.lazada.com.ph/products/2-in1-concealer-highlight-shadow-face-contouring-makeup-kiki-beauty-care-i1924312498.html',
#     'querystring': 'search=1&clickTrackInfo=query%253A%253Bnid%253A1924312498%253Bsrc%253ALazadaMainSrp%253Brn%253Adc973ea1b940bc80e9c3b6fb10fcd826%253Bregion%253Aph%253Bsku%253A1924312498_PH%253Bprice%253A27%253Bclient%253Adesktop%253Bsupplier_id%253A500173734222%253Basc_category_id%253A7708%253Bitem_id%253A1924312498%253Bsku_id%253A8229991020%253Bshop_id%253A2134505'},
#    {'name': '5Colors 4Heads Waterproof Eyebrow Pencil Pen Tint Cosmetic Natural Long Lasting Eyeliner Eyebrow Tattoo Gray Brown Makeup',
#     'nid': '3013909423',
#     'icons': [{'domClass': 'RveiUb',
#       'alias': 'RveiUb',
#       'type': 'img',
#       'group': '6',
#       'showType': '0',
#       'order': 0,
#       'font-size': 0,
#       'coins': False}],
#     'utLogMap': {'x_object_type': 'item',
#      'x_item_ids': '3013909423',
#      'scene_pre': 'search',
#      'current_price': '33.00',
#      'x_sku_ids': '14805671871',
#      'SN': 'dc973ea1b940bc80e9c3b6fb10fcd826',
#      'x_ad': '1',
#      'x_object_id': '3013909423'},
#     'image': 'https://ph-test-11.slatic.net/p/9f630333400e0ad658e1e9a4a8432927.jpg',
#     'originalPrice': '100.00',
#     'originalPriceShow': '₱100',
#     'price': '33.00',
#     'promotionId': 'null',
#     'priceShow': '₱33',
#     'discount': '-67%',
#     'ratingScore': '5.0',
#     'review': '30',
#     'installment': '',
#     'tItemType': 'nt_product',
#     'location': 'Metro Manila',
#     'cheapest_sku': '3013909423_PH-14805671871',
#     'sku': '3013909423_PH',
#     'skus': [],
#     'description': ['Origin : CN(Origin)',
#      'Formulation : Pencil',
#      'Waterproof / Water-Resistant : Yes',
#      'Size : Full Size',
#      'Number of Pieces : One Unit',
#      'Benefit : Long-lasting',
#      'Benefit : Easy to Wear',
#      'Type : Eyebrow Enhancer',
#      'Country/Region of Manufacture : China',
#      'Ingredient : eyebrow tattoo pen',
#      'Quantity : 1pcs',
#      'Model Number : 01,02,03,04,05',
#      'NET WT : 5G',
#      'Features 1 : liquid eyebrow pencil',
#      'Features 2 : 4 points eyebrow pen',
#      'Benefit : Natural',
#      'Type : Eyebrow Enhancer',
#      'feature 3: : waterproof eyebrow pencil'],
#     'brandId': '29872',
#     'brandName': 'No Brand',
#     'sellerId': '500163978549',
#     'mainSellerId': '',
#     'sellerName': 'LIN.',
#     'thumbs': [{'image': 'https://ph-live-01.slatic.net/p/049e91fdb6d341a6260aec1b5688e666.jpg',
#       'sku': '3013909423_PH',
#       'skuId': '14805671871',
#       'itemUrl': '/products/5colors-4heads-waterproof-eyebrow-pencil-pen-tint-cosmetic-natural-long-lasting-eyeliner-eyebrow-tattoo-gray-brown-makeup-i3013909423.html',
#       'querystring': ''}],
#     'restrictedAge': 0,
#     'categories': [7644, 5378, 5412, 5450],
#     'clickTrace': 'query:;nid:3013909423;src:LazadaMainSrp;rn:dc973ea1b940bc80e9c3b6fb10fcd826;region:ph;sku:3013909423_PH;price:33.00;client:desktop;supplier_id:500163978549;asc_category_id:5450;item_id:3013909423;sku_id:14805671871;shop_id:1539436',
#     'addToCartSkus': [{'sku': '3013909423_PH-14805671871',
#       'skuId': '14805671871',
#       'count': 0}],
#     'itemId': '3013909423',
#     'skuId': '14805671871',
#     'inStock': True,
#     'isAD': 0,
#     'addToCart': False,
#     'showFeedBack': False,
#     'longImageDisplayable': False,
#     'itemUrl': '//www.lazada.com.ph/products/5colors-4heads-waterproof-eyebrow-pencil-pen-tint-cosmetic-natural-long-lasting-eyeliner-eyebrow-tattoo-gray-brown-makeup-i3013909423.html',
#     'querystring': 'search=1&clickTrackInfo=query%253A%253Bnid%253A3013909423%253Bsrc%253ALazadaMainSrp%253Brn%253Adc973ea1b940bc80e9c3b6fb10fcd826%253Bregion%253Aph%253Bsku%253A3013909423_PH%253Bprice%253A33.00%253Bclient%253Adesktop%253Bsupplier_id%253A500163978549%253Basc_category_id%253A5450%253Bitem_id%253A3013909423%253Bsku_id%253A14805671871%253Bshop_id%253A1539436'},
#    {'name': 'Strong transparent false eyelash glue PA2048 128 198 F5 1088 06 07 108 138 319',
#     'nid': '352986486',
#     'icons': [{'domClass': 'RveiUb',
#       'alias': 'RveiUb',
#       'type': 'img',
#       'group': '6',
#       'showType': '0',
#       'order': 0,
#       'font-size': 0,
#       'coins': False}],
#     'utLogMap': {'x_object_type': 'item',
#      'x_item_ids': '352986486',
#      'scene_pre': 'search',
#      'current_price': '52.88',
#      'x_sku_ids': '796778412',
#      'SN': 'dc973ea1b940bc80e9c3b6fb10fcd826',
#      'x_ad': '1',
#      'x_object_id': '352986486'},
#     'image': 'https://ph-test-11.slatic.net/p/97f78bbe2b3a606abd80269599b756b8.jpg',
#     'originalPrice': '150.00',
#     'originalPriceShow': '₱150',
#     'price': '52.88',
#     'promotionId': 'null',
#     'priceShow': '₱52.88',
#     'discount': '-65%',
#     'ratingScore': '4.7451923076923075',
#     'review': '208',
#     'installment': '',
#     'tItemType': 'nt_product',
#     'location': 'Metro Manila',
#     'cheapest_sku': '352986486_PH-796778412',
#     'sku': '352986486_PH',
#     'skus': [],
#     'description': ['Product Name: False eyelash glue',
#      'Product content: 12mm',
#      'Product features: sticky false eyelashes / sticky double eyelids',
#      'Product effect: transparent, no trace, no skin damage, good adhesion taiwan eyelashes set',
#      '10 pairs',
#      '100% high quality products',
#      'Long lasting',
#      'Brand new',
#      'Operation method:',
#      '1. Use the tweezers to clip the extra eyelashes on both sides of the eyelashes, gently remove the eyelashes, and take care not to deform the eyelashes.',
#      '2. Gently remove the residual glue on the root of the eyelashes',
#      '3. Compare the length on your eyes',
#      '4. If it is too long, cut out the growing part.',
#      '5. Hold the eyelashes and bend them a few times to make it softer.',
#      '6. Apply glue to the root of the eyelashes for 15 seconds to allow the glue to dry.',
#      '7. Keep your eyelashes curled up during the waiting period',
#      '8. Use the auxiliary tweezers to help the false eyelashes stick to the upper side of the real eyelashes.',
#      '9. Adjust the angle when the glue is not completely dry.',
#      '10. Fill the eyeliner with eyeliner.'],
#     'brandId': '29872',
#     'brandName': 'No Brand',
#     'sellerId': '1000133050',
#     'mainSellerId': '',
#     'sellerName': 'm&y shop',
#     'thumbs': [{'image': 'https://ph-live-01.slatic.net/p/5a0a27d93d9c5eb1766fc5419b9cb40d.jpg',
#       'sku': '352986486_PH',
#       'skuId': '796778412',
#       'itemUrl': '/products/strong-transparent-false-eyelash-glue-pa2048-128-198-f5-1088-06-07-108-138-319-i352986486.html',
#       'querystring': ''},
#      {'image': 'https://ph-live-01.slatic.net/p/5448891f8fdc21d03b216c0874587123.jpg',
#       'sku': '352986486_PH',
#       'skuId': '13030688357',
#       'itemUrl': '/products/strong-transparent-false-eyelash-glue-pa2048-128-198-f5-1088-06-07-108-138-319-i352986486.html',
#       'querystring': ''},
#      {'image': 'https://ph-live-01.slatic.net/p/d37443257b93ff845e88556312265398.jpg',
#       'sku': '352986486_PH',
#       'skuId': '13030688358',
#       'itemUrl': '/products/strong-transparent-false-eyelash-glue-pa2048-128-198-f5-1088-06-07-108-138-319-i352986486.html',
#       'querystring': ''},
#      {'image': 'https://ph-live-01.slatic.net/p/924b1de4c4ca62baf9c0b4c00267ed20.jpg',
#       'sku': '352986486_PH',
#       'skuId': '13030688350',
#       'itemUrl': '/products/strong-transparent-false-eyelash-glue-pa2048-128-198-f5-1088-06-07-108-138-319-i352986486.html',
#       'querystring': ''},
#      {'image': 'https://ph-live-01.slatic.net/p/bf7b72405da2a90d18e41f262d9b28c7.jpg',
#       'sku': '352986486_PH',
#       'skuId': '13030688351',
#       'itemUrl': '/products/strong-transparent-false-eyelash-glue-pa2048-128-198-f5-1088-06-07-108-138-319-i352986486.html',
#       'querystring': ''},
#      {'image': 'https://ph-live-01.slatic.net/p/e801899ae9125fff84e25dc24d46eda5.jpg',
#       'sku': '352986486_PH',
#       'skuId': '13030688352',
#       'itemUrl': '/products/strong-transparent-false-eyelash-glue-pa2048-128-198-f5-1088-06-07-108-138-319-i352986486.html',
#       'querystring': ''},
#      {'image': 'https://ph-live-01.slatic.net/p/88a301557b0cc2abddf99f266101d604.jpg',
#       'sku': '352986486_PH',
#       'skuId': '13030688353',
#       'itemUrl': '/products/strong-transparent-false-eyelash-glue-pa2048-128-198-f5-1088-06-07-108-138-319-i352986486.html',
#       'querystring': ''}],
#     'restrictedAge': 0,
#     'categories': [7644, 5378, 5405, 24268],
#     'clickTrace': 'query:;nid:352986486;src:LazadaMainSrp;rn:dc973ea1b940bc80e9c3b6fb10fcd826;region:ph;sku:352986486_PH;price:52.88;client:desktop;supplier_id:1000133050;asc_category_id:24268;item_id:352986486;sku_id:796778412;shop_id:310131',
#     'addToCartSkus': [{'sku': '352986486_PH-796778412',
#       'skuId': '796778412',
#       'count': 0}],
#     'itemId': '352986486',
#     'skuId': '796778412',
#     'inStock': True,
#     'isAD': 0,
#     'addToCart': False,
#     'showFeedBack': False,
#     'longImageDisplayable': False,
#     'itemUrl': '//www.lazada.com.ph/products/strong-transparent-false-eyelash-glue-pa2048-128-198-f5-1088-06-07-108-138-319-i352986486.html',
#     'querystring': 'search=1&clickTrackInfo=query%253A%253Bnid%253A352986486%253Bsrc%253ALazadaMainSrp%253Brn%253Adc973ea1b940bc80e9c3b6fb10fcd826%253Bregion%253Aph%253Bsku%253A352986486_PH%253Bprice%253A52.88%253Bclient%253Adesktop%253Bsupplier_id%253A1000133050%253Basc_category_id%253A24268%253Bitem_id%253A352986486%253Bsku_id%253A796778412%253Bshop_id%253A310131'},
#    {'name': '10ml Black Painless False Eyelash Extension Glue Individual lash Extensions Fast Dry Long Lasting Eyelash Glue Tool',
#     'nid': '3069718990',
#     'icons': [],
#     'utLogMap': {'x_object_type': 'item',
#      'x_item_ids': '3069718990',
#      'scene_pre': 'search',
#      'current_price': '95.00',
#      'x_sku_ids': '15133848407',
#      'SN': 'dc973ea1b940bc80e9c3b6fb10fcd826',
#      'x_ad': '1',
#      'x_object_id': '3069718990'},
#     'image': 'https://sg-test-11.slatic.net/p/1e1e98c2b5f98c73415082f8a270d6d4.png',
#     'originalPrice': '199.00',
#     'originalPriceShow': '₱199',
#     'price': '95.00',
#     'promotionId': 'null',
#     'priceShow': '₱95',
#     'discount': '-52%',
#     'ratingScore': '5.0',
#     'review': '18',
#     'installment': '',
#     'tItemType': 'nt_product',
#     'location': 'Metro Manila',
#     'cheapest_sku': '3069718990_PH-15133848407',
#     'sku': '3069718990_PH',
#     'skus': [],
#     'description': ['property:1. No smell, no irritation, safe to use.2. Super strong adhesion and quick drying, not easy to fall off, more natural and charming.3. It can help you create long-lasting eyelashes and not hurt your real eyelashes.4. Improve lightning grafting performance and quick fix.5. A perfect and necessary tool for beginners to practice eyelash extensions.6. Suitable for professional salon or personal use.'],
#     'brandId': '6435',
#     'brandName': 'Unbranded',
#     'sellerId': '500203110707',
#     'mainSellerId': '',
#     'sellerName': 'WwW Beauty',
#     'thumbs': [{'image': 'https://sg-test-11.slatic.net/p/1e1e98c2b5f98c73415082f8a270d6d4.png',
#       'sku': '3069718990_PH',
#       'skuId': '15133848407',
#       'itemUrl': '/products/10ml-black-painless-false-eyelash-extension-glue-individual-lash-extensions-fast-dry-long-lasting-eyelash-glue-tool-i3069718990.html',
#       'querystring': ''}],
#     'restrictedAge': 0,
#     'categories': [7644, 5378, 5405, 24268],
#     'clickTrace': 'query:;nid:3069718990;src:LazadaMainSrp;rn:dc973ea1b940bc80e9c3b6fb10fcd826;region:ph;sku:3069718990_PH;price:95.00;client:desktop;supplier_id:500203110707;asc_category_id:24268;item_id:3069718990;sku_id:15133848407;shop_id:3094706',
#     'addToCartSkus': [{'sku': '3069718990_PH-15133848407',
#       'skuId': '15133848407',
#       'count': 0}],
#     'itemId': '3069718990',
#     'skuId': '15133848407',
#     'inStock': True,
#     'isAD': 0,
#     'addToCart': False,
#     'showFeedBack': False,
#     'longImageDisplayable': False,
#     'itemUrl': '//www.lazada.com.ph/products/10ml-black-painless-false-eyelash-extension-glue-individual-lash-extensions-fast-dry-long-lasting-eyelash-glue-tool-i3069718990.html',
#     'querystring': 'search=1&clickTrackInfo=query%253A%253Bnid%253A3069718990%253Bsrc%253ALazadaMainSrp%253Brn%253Adc973ea1b940bc80e9c3b6fb10fcd826%253Bregion%253Aph%253Bsku%253A3069718990_PH%253Bprice%253A95.00%253Bclient%253Adesktop%253Bsupplier_id%253A500203110707%253Basc_category_id%253A24268%253Bitem_id%253A3069718990%253Bsku_id%253A15133848407%253Bshop_id%253A3094706'},
#    {'name': 'COD diane medina  authentic  1 pad',
#     'nid': '3107396897',
#     'icons': [{'domClass': 'RveiUb',
#       'alias': 'RveiUb',
#       'type': 'img',
#       'group': '6',
#       'showType': '0',
#       'order': 0,
#       'font-size': 0,
#       'coins': False}],
#     'utLogMap': {'x_object_type': 'item',
#      'x_item_ids': '3107396897',
#      'scene_pre': 'search',
#      'current_price': '315.00',
#      'x_sku_ids': '15355330101',
#      'SN': 'dc973ea1b940bc80e9c3b6fb10fcd826',
#      'x_ad': '1',
#      'x_object_id': '3107396897'},
#     'image': 'https://filebroker-cdn.lazada.com.ph/kf/Sbb6d95c34885424a8d2c21c777dda6fbH.jpg',
#     'price': '315.00',
#     'promotionId': 'null',
#     'priceShow': '₱315',
#     'ratingScore': '5.0',
#     'review': '21',
#     'installment': '',
#     'tItemType': 'nt_product',
#     'location': 'Bulacan',
#     'cheapest_sku': '3107396897_PH-15355330101',
#     'sku': '3107396897_PH',
#     'skus': [],
#     'description': [],
#     'brandId': '29872',
#     'brandName': 'No Brand',
#     'sellerId': '500166009526',
#     'mainSellerId': '',
#     'sellerName': 'tripleAs 1599748309',
#     'thumbs': [{'image': 'https://filebroker-cdn.lazada.com.ph/kf/Sbb6d95c34885424a8d2c21c777dda6fbH.jpg',
#       'sku': '3107396897_PH',
#       'skuId': '15355330101',
#       'itemUrl': '/products/cod-diane-medina-authentic-1-pad-i3107396897.html',
#       'querystring': ''}],
#     'restrictedAge': 0,
#     'categories': [7644, 5378, 5405, 24269],
#     'clickTrace': 'query:;nid:3107396897;src:LazadaMainSrp;rn:dc973ea1b940bc80e9c3b6fb10fcd826;region:ph;sku:3107396897_PH;price:315.00;client:desktop;supplier_id:500166009526;asc_category_id:24269;item_id:3107396897;sku_id:15355330101;shop_id:1660883',
#     'addToCartSkus': [{'sku': '3107396897_PH-15355330101',
#       'skuId': '15355330101',
#       'count': 0}],
#     'itemId': '3107396897',
#     'skuId': '15355330101',
#     'inStock': True,
#     'isAD': 0,
#     'addToCart': False,
#     'showFeedBack': False,
#     'longImageDisplayable': False,
#     'itemUrl': '//www.lazada.com.ph/products/cod-diane-medina-authentic-1-pad-i3107396897.html',
#     'querystring': 'search=1&clickTrackInfo=query%253A%253Bnid%253A3107396897%253Bsrc%253ALazadaMainSrp%253Brn%253Adc973ea1b940bc80e9c3b6fb10fcd826%253Bregion%253Aph%253Bsku%253A3107396897_PH%253Bprice%253A315.00%253Bclient%253Adesktop%253Bsupplier_id%253A500166009526%253Basc_category_id%253A24269%253Bitem_id%253A3107396897%253Bsku_id%253A15355330101%253Bshop_id%253A1660883'},
#    {'name': 'Cetaphil Gentle Skin Cleansing Cloth 25 Pulls x2 (For Sensitive Skin / Fragrance Free)',
#     'nid': '589396224',
#     'icons': [{'domClass': 'RveiUb',
#       'alias': 'RveiUb',
#       'type': 'img',
#       'group': '6',
#       'showType': '0',
#       'order': 0,
#       'font-size': 0,
#       'coins': False},
#      {'url': 'https://gw.alicdn.com/tfs/TB1r3Rqi2zO3e4jSZFxXXaP_FXa-94-28.png',
#       'domClass': 'lazMall',
#       'alias': 'lazMall',
#       'type': 'img',
#       'style': {'width': 86, 'height': 28},
#       'group': '3',
#       'showType': '0',
#       'order': 0,
#       'font-size': 0,
#       'coins': False}],
#     'utLogMap': {'x_object_type': 'item',
#      'x_item_ids': '589396224',
#      'scene_pre': 'search',
#      'current_price': '638.00',
#      'x_sku_ids': '1612878863',
#      'SN': 'dc973ea1b940bc80e9c3b6fb10fcd826',
#      'x_ad': '1',
#      'x_object_id': '589396224'},
#     'image': 'https://ph-test-11.slatic.net/p/372147a4f0419355bb9aef6a6c802b13.jpg',
#     'price': '638.00',
#     'promotionId': 'null',
#     'priceShow': '₱638',
#     'ratingScore': '4.864661654135339',
#     'review': '133',
#     'installment': '',
#     'tItemType': 'nt_product',
#     'location': 'Rizal',
#     'cheapest_sku': '589396224_PH-1612878863',
#     'sku': '589396224_PH',
#     'skus': [],
#     'description': ['Bundle Contents: 1 Cetaphil Cleansing Cloths 25 Pulls and 1 FREE Cetaphil Cleansing Cloths 25 Pulls',
#      'Clinically proven to remove 98% of dirt &amp; makeup',
#      'Cleans without causing irritation',
#      'Frangrance Free',
#      'pH 5.5'],
#     'brandId': '2694',
#     'brandName': 'Cetaphil',
#     'sellerId': '1000173529',
#     'mainSellerId': '',
#     'sellerName': 'Cetaphil',
#     'thumbs': [{'image': 'https://ph-test-11.slatic.net/p/372147a4f0419355bb9aef6a6c802b13.jpg',
#       'sku': '589396224_PH',
#       'skuId': '1612878863',
#       'itemUrl': '/products/cetaphil-gentle-skin-cleansing-cloth-25-pulls-x2-for-sensitive-skin-fragrance-free-i589396224.html',
#       'querystring': ''}],
#     'restrictedAge': 0,
#     'categories': [7644, 5378, 5409],
# ...
#      'name': 'Manicure Kits & Accessories',
#      'image': 'https://sg-test-11.slatic.net/p/7dc1ed3be0ecf54efe6f1f6d99228bf0.jpg',
#      'id': '5454'},
#     {'url': '/shop-foundation/?item_id=3159914335&from=onesearch_category_5378',
#      'name': 'Foundation',
#      'image': 'https://ph-test-11.slatic.net/p/d985ecaeb0a87cdaa493634271653724.jpg',
#      'id': '5760'},
#     {'url': '/shop-eye-shadows/?item_id=2623681964&from=onesearch_category_5378',
#      'name': 'Eye Shadow',
#      'image': 'https://ph-test-11.slatic.net/p/199e37105a2ea8b7fe94df2d01c14e6f.jpg',
#      'id': '5453'},
#     {'url': '/shop-artificial-nails/?item_id=2337896288&from=onesearch_category_5378',
#      'name': 'Artificial Nails',
#      'image': 'https://ph-test-11.slatic.net/p/2d33075ef3c647ba0ef5b18525212093.png',
#      'id': '5456'},
#     {'url': '/shop-eye-liners-kajal/?item_id=2093869168&from=onesearch_category_5378',
#      'name': 'Eyeliners',
#      'image': 'https://ph-test-11.slatic.net/p/0cc18a741cedce560a09aa02eb00cb7a.jpg',
#      'id': '5451'},
#     {'url': '/shop-false-eyelashes/?item_id=2226432189&from=onesearch_category_5378',
#      'name': 'False Eyelashes\xa0',
#      'image': 'https://sg-test-11.slatic.net/p/6b5146ac7c871a3b67b9891ecdedd428.jpg',
#      'id': '24560'},
#     {'url': '/shop-nail-art-stickers/?item_id=2522032000&from=onesearch_category_5378',
#      'name': 'Nail Art & Stickers',
#      'image': 'https://ph-test-11.slatic.net/p/541014c685298dd4e5c51f68d462f7a5.jpg',
#      'id': '9459'},
#     {'url': '/shop-mascaras/?item_id=2718086145&from=onesearch_category_5378',
#      'name': 'Mascaras',
#      'image': 'https://ph-test-11.slatic.net/p/e391be4f3637eb1f5e3e0f60782a8971.jpg',
#      'id': '5452'},
#     {'url': '/shop-bb-cc-cream/?item_id=2685991833&from=onesearch_category_5378',
#      'name': 'BB & CC',
#      'image': 'https://ph-test-11.slatic.net/p/44ff38d86950ad9c7a13eec76e5f0557.jpg',
#      'id': '9457'},
#     {'url': '/shop-nail-polish/?item_id=876178353&from=onesearch_category_5378',
#      'name': 'Nail Polish',
#      'image': 'https://ph-test-11.slatic.net/p/e4af5173dd586571163263902d84debe.jpg',
#      'id': '5458'},
#     {'url': '/shop-compacts-powder/?item_id=464556264&from=onesearch_category_5378',
#      'name': 'Compacts & Powder',
#      'image': 'https://ph-test-11.slatic.net/p/38255e90f4b8cf5825991b38a71c46ec.jpg',
#      'id': '5431'},
#     {'url': '/shop-concealer/?item_id=2848792162&from=onesearch_category_5378',
#      'name': 'Concealer',
#      'image': 'https://sg-test-11.slatic.net/p/a715ad5eefdb4343acaf280926b28707.jpg',
#      'id': '5438'},
#     {'url': '/shop-blushes/?item_id=699358011&from=onesearch_category_5378',
#      'name': 'Blushes',
#      'image': 'https://ph-test-11.slatic.net/p/91341a7e130d1a3d4cdb04e9d0d49f9e.jpg',
#      'id': '5429'},
#     {'url': '/shop-lip-glosses/?item_id=2453808147&from=onesearch_category_5378',
#      'name': 'Lip Gloss',
#      'image': 'https://ph-test-11.slatic.net/p/c5ee0c2c138067898bd1d2fef920cf9d.jpg',
#      'id': '5445'},
#     {'url': '/shop-makeup-mirrors/?item_id=1682314660&from=onesearch_category_5378',
#      'name': 'Mirrors',
#      'image': 'https://ph-test-11.slatic.net/p/816f01179727787c311a6a580fb73fb8.jpg',
#      'id': '5466'},
#     {'url': '/shop-multi-function-makeup-palettes-and-sets/?item_id=2586454490&from=onesearch_category_5378',
#      'name': 'Multi-Function',
#      'image': 'https://sg-test-11.slatic.net/p/c0586d1e026d480a471d3385802996e5.jpg',
#      'id': '-10100741'}],
#    'utTrack': {'from': 'onesearch_category_5378'},
#    'title': '',
#    'bizId': 'onesearch_category_5378',
#    'pos': 0},
#   'campaignBanner': {'tItemType': 'nx_campaignBanner',
#    'items': [{'url': 'https://www.lazada.com.ph/shop/loreal/?banner_id=queiEn?banner_id=queiEn&from=onesearch_category_5378',
#      'cover': 'https://ossgw.alicdn.com/skyline-lazada/i8/6ca615c2b57c4e439901b5aa54eeba63-1360-480.jpg',
#      'st_time': '2022-07-22 00:00:00',
#      'end_time': '2022-07-24 23:59:59'},
#     {'url': 'https://www.lazada.com.ph/shop/estee-lauder/?banner_id=queiEn&from=onesearch_category_5378',
#      'cover': 'https://ossgw.alicdn.com/skyline-lazada/i8/053c612d908d4a21bb6f6b7c8c337839-1360-480.jpg',
#      'st_time': '2022-07-22 00:00:00',
#      'end_time': '2022-07-24 23:59:59'}],
#    'utTrack': {'from': 'onesearch_category_5378'},
#    'bizId': 'onesearch_category_5378',
#    'pos': 0},
#   'resultTips': {'tItemType': 'nt_resulttips',
#    'tips': '6221135 items found in {$0}',
#    'title': 'Makeup',
#    'brandLink': '',
#    'keywords': [{'text': 'Makeup'}]},
#   'linksInfo': [{'category_id': '5378',
#     'link_data': [{'link_text': 'Face',
#       'link_url': 'https://www.lazada.com.ph/shop-face-makeup-palettes-and-sets/'},
#      {'link_text': 'Eyes',
#       'link_url': 'https://www.lazada.com.ph/shop-eye-makeup-palettes-and-sets/'},
#      {'link_text': 'Multi-Function',
#       'link_url': 'https://www.lazada.com.ph/shop-multi-function-makeup-palettes-and-sets/'},
#      {'link_text': 'Makeup Palettes & Sets',
#       'link_url': 'https://www.lazada.com.ph/shop-makeup-palettes-and-sets/'},
#      {'link_text': 'Foundation',
#       'link_url': 'https://www.lazada.com.ph/shop-foundation/'},
#      {'link_text': 'Shampoo',
#       'link_url': 'https://www.lazada.com.ph/shop-mens-conditioners/'},
#      {'link_text': 'Hair Styling',
#       'link_url': 'https://www.lazada.com.ph/shop-mens-hair-styling/'},
#      {'link_text': 'Hair Treatments',
#       'link_url': 'https://www.lazada.com.ph/shop-mens-hair-treatments/'},
#      {'link_text': 'Hair Coloring',
#       'link_url': 'https://www.lazada.com.ph/shop-mens-hair-color/'},
#      {'link_text': 'Hair Care',
#       'link_url': 'https://www.lazada.com.ph/shop-mens-hair-care/'},
#      {'link_text': 'toy nails for kids',
#       'link_url': 'https://www.lazada.com.ph/tag/toy-nails-for-kids/'},
#      {'link_text': 'toy organizer storage box',
#       'link_url': 'https://www.lazada.com.ph/tag/toy-organizer-storage-box/'},
#      {'link_text': 'toy poodle bed',
#       'link_url': 'https://www.lazada.com.ph/tag/toy-poodle-bed/'},
#      {'link_text': 'toyota atf type 4',
#       'link_url': 'https://www.lazada.com.ph/tag/toyota-atf-type-4/'},
#      {'link_text': 'toyota engine oil vios',
#       'link_url': 'https://www.lazada.com.ph/tag/toyota-engine-oil-vios/'},
#      {'link_text': 'toyota fortuner break pads',
#       'link_url': 'https://www.lazada.com.ph/tag/toyota-fortuner-break-pads/'},
#      {'link_text': 'toys for adults women rechargable',
#       'link_url': 'https://www.lazada.com.ph/tag/toys-for-adults-women-rechargable/'},
#      {'link_text': 'tp link strip',
#       'link_url': 'https://www.lazada.com.ph/tag/tp-link-strip/'},
#      {'link_text': 'traditional tattoo machine',
#       'link_url': 'https://www.lazada.com.ph/tag/traditional-tattoo-machine/'},
#      {'link_text': 'tradizione',
#       'link_url': 'https://www.lazada.com.ph/tag/tradizione/'}],
#     'link_type': '2'},
#    {'category_id': '5378',
#     'link_data': [{'link_text': 'jader perfume',
#       'link_url': 'https://www.lazada.com.ph/tag/jader-perfume/'},
#      {'link_text': 'slippers liliw',
#       'link_url': 'https://www.lazada.com.ph/tag/slippers-liliw/'},
#      {'link_text': 'front tow hook nv350',
#       'link_url': 'https://www.lazada.com.ph/tag/front-tow-hook-nv350/'},
#      {'link_text': 'led bar light car alloy',
#       'link_url': 'https://www.lazada.com.ph/tag/led-bar-light-car-alloy/'},
#      {'link_text': 'shimano deore m6120',
#       'link_url': 'https://www.lazada.com.ph/tag/shimano-deore-m6120/'},
#      {'link_text': 'skippy 1 3kg',
#       'link_url': 'https://www.lazada.com.ph/tag/skippy-1-3kg/'},
#      {'link_text': '8gb ram laptop ddr4 3200mhz',
#       'link_url': 'https://www.lazada.com.ph/tag/8gb-ram-laptop-ddr4-3200mhz/'},
#      {'link_text': 'mikaela sling bag women',
#       'link_url': 'https://www.lazada.com.ph/tag/mikaela-sling-bag-women/'},
#      {'link_text': 'candlestick patterns',
#       'link_url': 'https://www.lazada.com.ph/tag/candlestick-patterns/'},
#      {'link_text': 'bike white bike bike',
#       'link_url': 'https://www.lazada.com.ph/tag/bike-white-bike-bike/'}],
#     'link_type': '3'}],
#   'LazadaDecoration': {'footer': '%3Ch2%3ECreate%20the%20Best%20Version%20of%20Yourself%20and%20Parade%20with%20Confidence%20with%20Makeup%3C%2Fh2%3E%0A%3Cp%3EMakeup%20is%20an%20essential%20part%20of%20your%20outlook%20as%20it%20helps%20you%20to%20create%20the%20first%20and%20everlasting%20impression%20wherever%20you%20go.%20With%20the%20revolution%20of%20the%20fashion%20industry%2C%20many%20brands%20started%20launching%20makeup%20products%20for%20specific%20skin%20types%20to%20make%20them%20more%20effective%20and%20consumer-friendly.%20Foundations%2C%20concealers%2C%20compact%20powder%2C%20loose%20powder%2C%20eyeliners%20mascaras%2C%20lip%20balms%2C%20lip%20gloss%2C%20lipsticks%2C%20blushes%2C%20bronzers%2C%20moisturizers%2C%20face%20creams%2C%20and%20hand%20creams%20are%20the%20most%20prominently%20used%20cosmetics%20by%20many%20people%20across%20the%20globe%20to%20enhance%20their%20features.%20Moisturizers%20play%20an%20important%20role%20in%20the%20skincare%20routine%20as%20it%20helps%20in%20keeping%20the%20derma%20hydrated%20and%20healthy.%3C%2Fp%3E%0A%3Cp%3EThese%20products%20are%20made%20using%20natural%20ingredients%20and%20are%20safe%20to%20use.%20They%20are%20loaded%20with%20antioxidants%20and%20Vitamin%20E.%20Along%20with%20keeping%20the%20skin%20hydrated%2C%20it%20also%20helps%20in%20removing%20blemishes%2C%20scars%2C%20and%20acne.%20While%20moisturizers%20act%20as%20a%20base%20makeup%20product%2C%20primers%20and%20concealers%20would%20help%20you%20to%20get%20a%20clean%20Canvas%20to%20complete%20the%20look.%20Both%20these%20essential%20oils%20are%20also%20available%20in%20various%20skin%20tones%20that%20can%20be%20chosen%20according%20to%20your%20complexion.%20With%20the%20application%20of%20these%20cosmetics%2C%20you%20would%20be%20able%20to%20even%20out%20your%20skin%20tone%20and%20prepare%20it%20for%20further%20processes%20effectively.%20Along%20with%20this%2C%20it%20is%20also%20mandatory%20to%20choose%20the%20right%20kind%20of%20powder%20as%20it%20helps%20in%20preventing%20the%20accumulation%20of%20dirt%20and%20grime%20from%20your%20face.%3C%2Fp%3E%0A%3Ch2%3EFlaunt%20Around%20like%20a%20Diva%20Wherever%20You%20Go%20with%20the%20Right%20Makeup%3C%2Fh2%3E%0A%3Cp%3EPowders%20available%20these%20days%20are%20loaded%20with%20a%20variety%20of%20minerals%20that%20penetrate%20the%20deeper%20layers%20of%20the%20skin%20and%20nourish%20it%20from%20the%20core.%20All%20the%20skincare%20products%20are%20free%20of%20paraben%2C%20sulfate%2C%20and%20phthalate.%20Therefore%2C%20they%20are%20suitable%20for%20people%20with%20sensitive%20skin%20as%20well.%20You%20would%20be%20able%20to%20complete%20your%20look%20by%20highlighting%20it%20using%20eyeshadows%20and%20blushes%20of%20various%20hues%20and%20shades.%20You%20would%20be%20able%20to%20achieve%20different%20kinds%20of%20looks%2C%20depending%20upon%20the%20attire%20and%20season%2C%20by%20using%20these%20cosmetics.%20They%20are%20available%20as%20a%20single%20unit%20or%20as%20a%20palette%20with%20multiple%20colors%20and%20shades%20that%20can%20be%20chosen%20according%20to%20preference%20and%20requirements.%3C%2Fp%3E%0A%3Cp%3EMany%20ladies%20also%20highlight%20their%20eyes%20using%20mascaras%20and%20eyeliners%20of%20different%20colors%20such%20as%20green%2C%20blue%2C%20black%2C%20brown%2C%20and%20white%20since%20it%20increases%20the%20overall%20aesthetic%20appeal%20instantly.%20All%20these%20essentials%20are%20tested%20dermatologically%20by%20experts%20in%20the%20laboratories%20before%20being%20released%20into%20the%20consumer%20market.%20Therefore%2C%20they%20are%20extremely%20safe.%20They%20are%20compact%20and%20lightweight%3B%20thus%2C%20carrying%20them%20in%20your%20handbags%20or%20pouches%20would%20not%20be%20a%20hassle.%20Flaunt%20around%20with%20radiant%20skin%20wherever%20you%20go%20by%20investing%20in%20beauty%20makeup%20essentials.%3C%2Fp%3E'}},
#  'mainInfo': {'errorMsg': '',
#   'bizCode': 0,
#   'isShowFloatCart': False,
#   'isHideAddToCart': False,
#   'totalResults': '4080',
#   'pageSize': '40',
#   'page': '1',
#   'RN': 'dc973ea1b940bc80e9c3b6fb10fcd826',
#   'style': 'wf',
#   'layoutInfo': {'listHeader': ['shopBanner',
#     'campaignBanner',
#     'categoryBar',
#     'brandBar',
#     'resultTips',
#     'didYouMean',
#     'promotionfilter',
#     'superStore',
#     'navCategory',
#     'banner',
#     'hotDeal',
#     'emptyResult',
#     'recQuery'],
#    'stickyHeader': ['sortBar', 'preposeFilter'],
#    'sceneHeader': ['sceneHeader']},
#   'pageType': 'SearchListCategory',
#   'gridTitleLine': '2',
#   'trackParams': {'categoryAsc': '5378', 'category': '5378'},
#   'categoryRegionalKey': '080800000000',
#   'mainCategoryRegionalKey': '080000000000',
#   'pageTitle': 'Makeup brands - Beauty Makeup on sale, prices, set & reviews in Philippines | Lazada Philippines',
#   'cate_id': '',
#   'hyperspaceInfo': '',
#   'lang': 'en',
#   'venture': 'PH',
#   'currency': '₱',
#   'currencyOnRight': 'false',
#   'currencySpace': 'false',
#   'isShowFeedbackForm': 'false',
#   'showThumbs': 'false',
#   'addToCartURL': '//cart.lazada.com.ph/cart/api/add',
#   'themes': [{'key': 'freeShipping',
#     'isImgIcon': '1',
#     'url': '//laz-img-cdn.alicdn.com/tfs/TB1QTkMXG67gK0jSZFHXXa9jVXa-45-28.png',
#     'locaLang': '',
#     'enLang': '',
#     'style': '{width: 45, height: 28}',
#     'text': ''},
#    {'key': 'lazMall',
#     'isImgIcon': '1',
#     'url': 'https://gw.alicdn.com/tfs/TB1r3Rqi2zO3e4jSZFxXXaP_FXa-94-28.png',
#     'locaLang': '',
#     'enLang': '',
#     'style': '{width: 86, height: 28}',
#     'text': ''},
#    {'key': 'lazGlobal',
#     'isImgIcon': '1',
#     'url': '//laz-img-cdn.alicdn.com/tfs/TB1Un_6Bvb2gK0jSZK9XXaEgFXa-98-28.png',
#     'locaLang': '',
#     'enLang': '',
#     'style': '{width: 98, height: 28}',
#     'text': ''},
#    {'key': '7ZRRj2',
#     'isImgIcon': '1',
#     'url': '//gcp-img.slatic.net/lazada/id0013949-60-28.png',
#     'locaLang': '',
#     'enLang': '',
#     'style': '{width: 60, height: 28}',
#     'text': ''},
#    {'key': 'newArrival',
#     'isImgIcon': '1',
#     'url': '//laz-img-cdn.alicdn.com/tfs/TB1J_NdbROD3KVjSZFFXXcn9pXa-62-28.png',
#     'locaLang': '',
#     'enLang': '',
#     'style': '{width: 62, height: 28}',
#     'text': ''},
#    {'key': 'MvUJJz',
#     'isImgIcon': '1',
#     'url': '//laz-img-cdn.alicdn.com/tfs/TB1UZp2jYj1gK0jSZFuXXcrHpXa-54-28.png',
#     'locaLang': '',
#     'enLang': '',
#     'style': '{width: 54, height: 28}',
#     'text': ''},
#    {'key': 'Zneai2',
#     'isImgIcon': '1',
#     'url': '//laz-img-cdn.alicdn.com/tfs/TB1SY7noEH1gK0jSZSyXXXtlpXa-56-28.png',
#     'locaLang': '',
#     'enLang': '',
#     'style': '{width: 56, height: 28}',
#     'text': ''},
#    {'key': 'RRNjma',
#     'isImgIcon': '1',
#     'url': '//gcp-img.slatic.net/lazada/id0083926-56-28.png',
#     'locaLang': '',
#     'enLang': '',
#     'style': '{width: 56, height: 28}',
#     'text': ''},
#    {'key': 'FRn6be',
#     'isImgIcon': '1',
#     'url': '//gcp-img.slatic.net/lazada/id0034875-56-28.png',
#     'locaLang': '',
#     'enLang': '',
#     'style': '{width: 56, height: 28}',
#     'text': ''},
#    {'key': 'UbIrYj',
#     'isImgIcon': '1',
#     'url': '//gcp-img.slatic.net/lazada/id0031020-56-28.png',
#     'locaLang': '',
#     'enLang': '',
#     'style': '{width: 56, height: 28}',
#     'text': ''},
#    {'key': 'YRf6zy',
#     'isImgIcon': '1',
#     'url': 'http://gcp-img.slatic.net/lazada/id0041789-56-28.png',
#     'locaLang': '',
#     'enLang': '',
#     'style': '{width: 56, height: 28}',
#     'text': ''},
#    {'key': 'redmart',
#     'isImgIcon': '1',
#     'url': '//laz-img-cdn.alicdn.com/tfs/TB1zV.YcAL0gK0jSZFAXXcA9pXa-88-28.png',
#     'locaLang': '',
#     'enLang': '',
#     'style': '{width: 88, height: 28}',
#     'text': ''}],
#   'q': '',
#   'column': 2,
#   'bucketId': 'v1',
#   'auctionType': 1,
#   'selectedFilters': {'categoryAsc': '5378', 'category': '5378'},
#   'reqParams': '{"src":"h5_internal","refer":"https://www.lazada.com.ph/shop-makeup/","scenario":"keyword-dynamic","ab_test":"BASE:0"}'}}

# %%
data['mods'].keys()
# Out:
# dict_keys(['filter', 'listItems', 'breadcrumb', 'sortBar', 'categoryBar', 'campaignBanner', 'resultTips', 'linksInfo', 'LazadaDecoration'])

# %%
for item in data['mods']['listItems']:
    print(item['name'])
# Out:
# Vinka Organic green tea Facial Tissue 3 ply (480 sheets） x 8 Packs
# MAS SHOP vinka Organic Facial Tissue 3 ply (360 sheets x 8 Packs)
# F.six Liquid eyeliner pen is waterproof and sweatproof, long-lasting and does not smudge eyeliner FS ✨Buy ₱199 Free shipping✨✌
# U HOME vinka Organic Facial Tissue 3 ply (360 sheets x 8 Packs)
# SUNISA Mushroom Head Air Cushion BB CC Cream (With Sponge)
# 2 In1 Concealer Highlight Shadow Face Contouring Makeup Kiki Beauty & Care
# 5Colors 4Heads Waterproof Eyebrow Pencil Pen Tint Cosmetic Natural Long Lasting Eyeliner Eyebrow Tattoo Gray Brown Makeup
# Strong transparent false eyelash glue PA2048 128 198 F5 1088 06 07 108 138 319
# 10ml Black Painless False Eyelash Extension Glue Individual lash Extensions Fast Dry Long Lasting Eyelash Glue Tool
# COD diane medina  authentic  1 pad
# Cetaphil Gentle Skin Cleansing Cloth 25 Pulls x2 (For Sensitive Skin / Fragrance Free)
# Shuta Organic Facial Tissue 3 ply (450 sheets） x 8 Packs
# BOBBIE COSMETICS Beauty Tools - Eyelash Adhesive Glue 2ml
# 🔥🔥Roman Holiday  Eyeliner pencil black is waterproof and sweatproof, long-lasting and does not smudge make up eyeliner pencil brown set liquid eyeliner set COD
# MAS SHOP Shuta Organic Facial Tissue 3 ply (450 sheets x 8 Packs)
# [Charming] Liquid Star Eyeliner Water-proof Long-Lasting
# MAS GOODS Vinka Organic green tea Facial Tissue 3 ply (480 sheets x 8 Packs)
# CiCi MART LAYDEE BEAUTE New Waterproof With 10 Kinds Reusable Eyebrow Stencils Brow Stamp Shaping Kit
# Eyebrow Pencil Waterproof Tint Natural Long Lasting Paint Tattoo Eyebrow
# HSM Original Waterproof Sunisa Natural Brightening Beauty Make-up Mushroom Head Air Cushion BB Cream
# Crystal 168 Vinka Organic Facial Tissue 3 ply (360 sheets x 8 Packs)
# [Kelvin Online Preferred] 3Pcs Eyebrow Razor Facial Hair Remover Eyebrow Trimmer Sharp Mini Makeup Knife Shaper Shaver
# Ashley Shine Perfect Glow BB Cream 45g Liquid Fundation Oil Control Full Coverage Make Up AS8094
# PAULASH CLEAR GLUE (5ML) •Up to 600x of use
# Vinka Organic Facial Tissue 3 ply (360 sheets） x 8 Packs
# Eyebrow Soap Brow Sculpt Lift Brow Styling Soap Waterproof Long Lasting Eyebrow Gel Pomade Eyebrow
# ❤ BUY 1 TAKE 1 ❤ BB Cream CC Cream Sunisa Cream ORIGINAL Mushroom Head Air Authentic Original Waterproof Foudation Natural Brightening Beauty Make-up Mushroom Head Air Cushion BB Cream Long Lasting Foundation Oil Control Moisturizing Liquid Foundation
# MAS SHOP huazi Organic Facial Tissue Imported raw wood pulp big paper tissue 250x2ply（8pcs/pack）
# TPS The Premium Stain - Matte and gel creamy Tint blushes 100% authentic original legit Fast Xonia Anya Annasophia Keila Miah Bella Eliyah Katrina Isobelle Daniella Gabriella make Up Light weight long wearing Safe BFAD Approved The Premium Stain Matte
# MELEDE 12ml Clear Eyelash Glue Waterproof Lash Glue Mink Eyelashes Glue Eye Lash Adhesive Black False Eyelash Accessories Cosmetic Tool
# 2 In1 Winged Stamp Liquid Eyeliner Pencil Eyes Makeup Waterproof Fast Dry Lasting Cosmetics Black Stamps Seal Eyeliner Pen TSLM1
# Crystal 168 Vinka Green Tea Roll Bathroom Tissue 10rolls
# Anastasia Beverlyhills Dipbrow Pomade with FREE Dou Brush
# JUNO Skin Clean 10 Cleansing Balm
# 1 PC Waterproof Eyebrow Pencil
# [Best seller first] 100ml Makeup Spray Oil Control Makeup Setting Spray Moisturizing Finishing Spray Long Lasting Face Foundation Make Up Mist Matte Base Retainer Makeup Spray
# The Ordinary High-Adherence Silicone Primer - 30ml
# [buy one get one free]nail repair essence Nail care fix nail onychomycosis nail fungus treatment nail repair treatment cream essence footurel gel anti fungal nail care repair remove onychomycosis anti-cracking antibacterial treatment fix bad nails
# Authentic Korean IOPE Air Cushion with +FREE Refill Cushion SPF 50+++ (30 Grams) +FREE GIFT | Face Make Up Foundation Korean Make Up BB Cream Sweat Proof | Fashion Pinas Store | Our Best Seller IOPE Air Cushion 2022
# G21 POREFECT BLURR Mattifying Primer Original | G21 POREfect Blurr Original COD | Transparent Primer Lightweight and Moisturizing Pore-Blurring that smooths out fine lines and imperfections. Silky Smooth Skin velvety matte feeling | KC Onliine Shop Main
